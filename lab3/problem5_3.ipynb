# %%
from docplex.mp.model import Model
import numpy as np
from RandomNumberGenerator import RandomNumberGenerator
import math
import os

# %%
class RandomNumberGenerator:
    def __init__(self, seedVaule = None):
        self.__seed = seedVaule

    def nextInt(self, low, high):
        m = 2147483647
        a = 16807
        b = 127773
        c = 2836
        
        k = int(self.__seed / b)
        self.__seed = a * (self.__seed % b) - k * c

        if self.__seed < 0:
            self.__seed = self.__seed + m

        value_0_1 = self.__seed
        value_0_1 =  value_0_1/m
        
        return low + int(math.floor(value_0_1 * (high - low + 1)))
    

    def nextFloat(self, low, high):
        low *= 100000
        high *= 100000
        val = self.nextInt(low, high) / 100000.0
        
        return val
    

# INPUT VARIABLES: ---------------
seed = 42
r = RandomNumberGenerator(seed)
min_n = 2
max_n = 50
# ----------------------------------

def get_var(n: int):
    c = [0] * n
    w = [0] * n
    v = [0] * n
    for i in range(n):
        c[i] = r.nextFloat(1, 10)
        w[i] = r.nextFloat(1, 10)
        v[i] = r.nextFloat(1, 10)

    B = r.nextFloat(n, 4*n) 
    return c, w, v, B

# %%
import re
import io

def get_ticks(s: str):
    print(s)
    match = re.search(r'\(([-+]?\d*\.?\d+)\s+ticks\)', s)
    if match:
        return float(match.group(1))
    else:
        return None

# %%
def solve_5_3(n):
    model = Model(name='example')
    # init values
    c, w, v, B = get_var(n)


    x = [model.continuous_var(name=f'x_{i}') for i in range(n)]
    y = [model.continuous_var(name=f'y_{i}') for i in range(n)]

    # constraints
    for i in range(n):
        model.add_constraint(x[i] + y[i] <= 1)
        model.add_constraint(x[i] >= 0)
        model.add_constraint(y[i] >= 0)
        
    
    model.add_constraint(model.sum(x[i] * w[i] for i in range(n)) <= B)
    model.add_constraint(model.sum(y[i] * v[i] for i in range(n)) <= B)
    
    # maximize
    total_cost = model.sum((x[i] + y[i]) * c[i] for i in range(n))
    model.maximize(total_cost)    
    
    log_buffer = io.StringIO()
    solution = model.solve(log_output=log_buffer)
    
    
    if not solution:
        raise Exception("No solution found")
    
    solution_x = [x[i].solution_value for i in range(n)]
    solution_y = [y[i].solution_value for i in range(n)]
    
    total_cost = solution.get_objective_value()
    
    # for i in range(n):
    #     print(f"[{i}] x_{i}: {solution_x[i]}, y_{i}: {solution_y[i]}")
        
    return total_cost, get_ticks(log_buffer.getvalue())

# %%
import pandas as pd


reps = 20
ns = range(5, 331, 5)

result = []
for n in ns:
    res = []
    print(f"n = {n}")
    for i in range(reps):
        solution, ticks = solve_5_3(n)
        res.append(ticks)
    result.append([n, np.mean(res), np.std(res)])
    
df = pd.DataFrame(result, columns=['n', 'ticks_mean', 'ticks_std'])
df.to_csv('5_3.csv', index=False)
print(df)
# Out:
# n = 5
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            26.574376
# Iteration:     3   Dual objective     =            39.448513
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            26.020826
# Iteration:     3   Dual objective     =            21.357685
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            23.569926
# Iteration:     3   Dual objective     =            24.895175
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            25.742076
# Iteration:     3   Dual objective     =            52.985215
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            24.628446
# Iteration:     3   Dual objective     =            54.315363
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            38.007976
# Iteration:     3   Dual objective     =            49.129514
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            16.459506
# Iteration:     3   Dual objective     =            24.751692
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            17.037566
# Iteration:     3   Dual objective     =            22.624810
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            24.523316
# Iteration:     3   Dual objective     =            34.058086
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            25.029966
# Iteration:     3   Dual objective     =            48.008218
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            31.668796
# Iteration:     3   Dual objective     =            35.576645
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            25.454236
# Iteration:     3   Dual objective     =            35.106262
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            25.958336
# Iteration:     3   Dual objective     =            67.465048
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 12 rows and 5 columns.
# Aggregator did 5 substitutions.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            30.878646
# Iteration:     3   Dual objective     =           114.759967
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            34.095816
# Iteration:     3   Dual objective     =            62.169777
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            28.508106
# Iteration:     3   Dual objective     =            77.846279
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            29.949736
# Iteration:     3   Dual objective     =            77.908319
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            28.207676
# Iteration:     3   Dual objective     =            68.799131
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 10 rows and 0 columns.
# Reduced LP has 7 rows, 10 columns, and 20 nonzeros.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            18.415246
# Iteration:     3   Dual objective     =            17.904691
#
# n = 10
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            37.557731
# Iteration:     3   Dual objective     =            88.037100
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            51.400741
# Iteration:     3   Dual objective     =            69.765424
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            53.452871
# Iteration:     3   Dual objective     =           170.103783
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            53.931491
# Iteration:     3   Dual objective     =           211.065033
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            71.660361
# Iteration:     3   Dual objective     =            91.384387
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            65.911451
# Iteration:     3   Dual objective     =           244.157819
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            66.857461
# Iteration:     3   Dual objective     =           289.067805
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            61.969231
# Iteration:     3   Dual objective     =           100.122222
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            46.096381
# Iteration:     3   Dual objective     =           135.102918
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            63.495431
# Iteration:     3   Dual objective     =           247.319907
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            67.013911
# Iteration:     3   Dual objective     =           276.695079
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            52.749551
# Iteration:     3   Dual objective     =           298.583908
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            43.156631
# Iteration:     3   Dual objective     =           177.473219
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            48.340961
# Iteration:     3   Dual objective     =            44.606786
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            56.907831
# Iteration:     3   Dual objective     =           239.286897
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            57.533811
# Iteration:     3   Dual objective     =           199.638341
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            43.620881
# Iteration:     3   Dual objective     =           152.080103
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            54.945981
# Iteration:     3   Dual objective     =           190.115767
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            29.522061
# Iteration:     3   Dual objective     =            38.803987
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 20 rows and 0 columns.
# Reduced LP has 12 rows, 20 columns, and 40 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            38.906141
# Iteration:     3   Dual objective     =            44.967182
#
# n = 15
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            77.720586
# Iteration:     3   Dual objective     =           363.649080
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            72.515536
# Iteration:     3   Dual objective     =           245.039397
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            68.157126
# Iteration:     3   Dual objective     =           230.821217
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            79.083586
# Iteration:     3   Dual objective     =           447.546366
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           103.130876
# Iteration:     3   Dual objective     =           422.371617
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            90.891136
# Iteration:     3   Dual objective     =           128.506021
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            65.888286
# Iteration:     3   Dual objective     =           293.503568
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            79.264886
# Iteration:     3   Dual objective     =           169.972805
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            83.978336
# Iteration:     3   Dual objective     =           162.532698
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           104.133196
# Iteration:     3   Dual objective     =           372.340229
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            89.784736
# Iteration:     3   Dual objective     =           213.424174
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            73.862916
# Iteration:     3   Dual objective     =           143.099282
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            78.247166
# Iteration:     3   Dual objective     =            94.067072
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            81.747506
# Iteration:     3   Dual objective     =           193.103463
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            83.528026
# Iteration:     3   Dual objective     =           445.006328
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            85.436256
# Iteration:     3   Dual objective     =           180.256436
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            90.383116
# Iteration:     3   Dual objective     =           236.439721
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           101.503876
# Iteration:     3   Dual objective     =           179.331027
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            76.347096
# Iteration:     3   Dual objective     =           618.458251
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 30 rows and 0 columns.
# Reduced LP has 17 rows, 30 columns, and 60 nonzeros.
# Presolve time = 0.00 sec. (0.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            92.545346
# Iteration:     3   Dual objective     =           185.462880
#
# n = 20
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           114.622421
# Iteration:     3   Dual objective     =           519.828528
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           131.782671
# Iteration:     3   Dual objective     =           260.218996
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           125.429411
# Iteration:     3   Dual objective     =           165.933836
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           118.632421
# Iteration:     3   Dual objective     =           242.011104
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           124.213041
# Iteration:     3   Dual objective     =           256.144296
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            98.600951
# Iteration:     3   Dual objective     =           563.258480
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           106.739611
# Iteration:     3   Dual objective     =           352.086926
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           105.622051
# Iteration:     3   Dual objective     =           335.817654
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            97.409421
# Iteration:     3   Dual objective     =           273.365100
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           113.850251
# Iteration:     3   Dual objective     =           179.218534
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           105.616781
# Iteration:     3   Dual objective     =           712.523595
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           116.579791
# Iteration:     3   Dual objective     =           137.208885
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           101.966891
# Iteration:     3   Dual objective     =           589.437222
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           137.960681
# Iteration:     3   Dual objective     =           479.049354
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           102.639401
# Iteration:     3   Dual objective     =           517.703676
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           122.476671
# Iteration:     3   Dual objective     =           474.886888
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           125.392631
# Iteration:     3   Dual objective     =           480.218901
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           118.033171
# Iteration:     3   Dual objective     =           442.279274
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =            93.656151
# Iteration:     3   Dual objective     =           333.584448
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 40 rows and 0 columns.
# Reduced LP has 22 rows, 40 columns, and 80 nonzeros.
# Presolve time = 0.00 sec. (0.04 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           118.242291
# Iteration:     3   Dual objective     =           322.592967
#
# n = 25
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           127.681236
# Iteration:     3   Dual objective     =           716.955029
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           120.164896
# Iteration:     3   Dual objective     =           401.257293
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           139.095146
# Iteration:     3   Dual objective     =           775.018489
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           118.512186
# Iteration:     3   Dual objective     =           670.070034
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           125.618116
# Iteration:     3   Dual objective     =           234.291827
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           119.025986
# Iteration:     3   Dual objective     =           400.385730
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           149.617176
# Iteration:     3   Dual objective     =           332.734516
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           133.609426
# Iteration:     3   Dual objective     =           257.134244
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           165.158166
# Iteration:     3   Dual objective     =           936.445239
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           129.738266
# Iteration:     3   Dual objective     =           575.211829
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           135.696226
# Iteration:     3   Dual objective     =           697.940851
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           138.498506
# Iteration:     3   Dual objective     =           676.424149
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           121.953576
# Iteration:     3   Dual objective     =           654.912438
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           137.446686
# Iteration:     3   Dual objective     =           608.808621
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           108.287346
# Iteration:     3   Dual objective     =           437.799671
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           142.173406
# Iteration:     3   Dual objective     =           586.052988
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           137.210196
# Iteration:     3   Dual objective     =           443.782030
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           146.782126
# Iteration:     3   Dual objective     =           432.069738
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           143.724306
# Iteration:     3   Dual objective     =           589.768254
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 50 rows and 0 columns.
# Reduced LP has 27 rows, 50 columns, and 100 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           123.060966
# Iteration:     3   Dual objective     =           663.660609
#
# n = 30
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           171.294541
# Iteration:     3   Dual objective     =           655.256606
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           160.031251
# Iteration:     3   Dual objective     =          1024.447849
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           167.729561
# Iteration:     3   Dual objective     =           827.477949
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           171.036551
# Iteration:     3   Dual objective     =          1000.950139
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           171.074351
# Iteration:     3   Dual objective     =           696.991870
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           168.960741
# Iteration:     3   Dual objective     =           497.987669
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           181.331281
# Iteration:     3   Dual objective     =           529.689885
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           179.591451
# Iteration:     3   Dual objective     =          1608.806099
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           169.578141
# Iteration:     3   Dual objective     =           924.790367
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           177.387221
# Iteration:     3   Dual objective     =           361.241555
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           172.548371
# Iteration:     3   Dual objective     =           325.142323
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           159.424501
# Iteration:     3   Dual objective     =           702.948036
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           168.240101
# Iteration:     3   Dual objective     =           754.151142
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           159.106041
# Iteration:     3   Dual objective     =           699.468691
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           178.847591
# Iteration:     3   Dual objective     =           647.712249
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =           186.137701
# Iteration:     3   Dual objective     =           534.066972
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 60 rows and 0 columns.
# Reduced LP has 32 rows, 60 columns, and 120 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
#
# ...
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.02 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1842.470831
# Iteration:     3   Dual objective     =         15267.605430
# Iteration:    64   Dual objective     =          6544.754193
# Iteration:   126   Dual objective     =          4156.129711
# Iteration:   188   Dual objective     =          3023.120314
# Iteration:   250   Dual objective     =          2556.534028
# Iteration:   312   Dual objective     =          2129.713939
# Iteration:   374   Dual objective     =          1842.471160
# Perturbation started.
# Iteration:   411   Dual objective     =          1842.471160
# Iteration:   473   Dual objective     =          1842.471147
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1801.310141
# Iteration:     3   Dual objective     =         15167.639958
# Iteration:    64   Dual objective     =          6471.657036
# Iteration:   126   Dual objective     =          4068.033402
# Iteration:   188   Dual objective     =          3163.545392
# Iteration:   250   Dual objective     =          2535.861293
# Iteration:   312   Dual objective     =          2092.063833
# Iteration:   374   Dual objective     =          1801.310470
# Perturbation started.
# Iteration:   411   Dual objective     =          1801.310470
# Iteration:   473   Dual objective     =          1801.310453
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1783.945961
# Iteration:     3   Dual objective     =         11843.354586
# Iteration:    64   Dual objective     =          4254.688646
# Iteration:   126   Dual objective     =          2835.020965
# Iteration:   188   Dual objective     =          2220.398125
# Iteration:   250   Dual objective     =          1966.749875
# Iteration:   312   Dual objective     =          1825.726574
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.02 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1816.894901
# Iteration:     3   Dual objective     =         16735.977317
# Iteration:    64   Dual objective     =          7846.919871
# Iteration:   126   Dual objective     =          4991.234509
# Iteration:   188   Dual objective     =          3792.830593
# Iteration:   250   Dual objective     =          2851.325434
# Iteration:   312   Dual objective     =          2205.425614
# Iteration:   374   Dual objective     =          1816.895230
# Perturbation started.
# Iteration:   411   Dual objective     =          1816.895230
# Iteration:   473   Dual objective     =          1816.895158
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1815.338491
# Iteration:     3   Dual objective     =         14712.379919
# Iteration:    64   Dual objective     =          6756.308193
# Iteration:   126   Dual objective     =          4092.674290
# Iteration:   188   Dual objective     =          3164.565300
# Iteration:   250   Dual objective     =          2475.599664
# Iteration:   312   Dual objective     =          2086.850786
# Iteration:   374   Dual objective     =          1815.338820
# Perturbation started.
# Iteration:   411   Dual objective     =          1815.338820
# Iteration:   473   Dual objective     =          1815.338806
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1822.629091
# Iteration:     3   Dual objective     =         19549.436308
# Iteration:    64   Dual objective     =          7526.391886
# Iteration:   126   Dual objective     =          4493.712399
# Iteration:   188   Dual objective     =          3250.142004
# Iteration:   250   Dual objective     =          2645.150789
# Iteration:   312   Dual objective     =          2177.164683
# Iteration:   374   Dual objective     =          1822.629420
# Perturbation started.
# Iteration:   411   Dual objective     =          1822.629420
# Iteration:   473   Dual objective     =          1822.629382
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1774.283071
# Iteration:     3   Dual objective     =         17814.915212
# Iteration:    64   Dual objective     =          8107.691716
# Iteration:   126   Dual objective     =          5487.331531
# Iteration:   188   Dual objective     =          3750.526285
# Iteration:   250   Dual objective     =          3005.866264
# Iteration:   312   Dual objective     =          2256.479604
# Iteration:   374   Dual objective     =          1774.283400
# Perturbation started.
# Iteration:   411   Dual objective     =          1774.283400
# Iteration:   473   Dual objective     =          1774.283318
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1791.381711
# Iteration:     3   Dual objective     =         12220.480079
# Iteration:    64   Dual objective     =          5896.991685
# Iteration:   126   Dual objective     =          3513.176055
# Iteration:   188   Dual objective     =          2750.996452
# Iteration:   250   Dual objective     =          2406.962094
# Iteration:   312   Dual objective     =          1964.564853
# Iteration:   374   Dual objective     =          1791.382040
# Perturbation started.
# Iteration:   411   Dual objective     =          1791.382040
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1829.467281
# Iteration:     3   Dual objective     =         11503.564079
# Iteration:    64   Dual objective     =          4373.922429
# Iteration:   126   Dual objective     =          2972.339947
# Iteration:   188   Dual objective     =          2467.560113
# Iteration:   250   Dual objective     =          2177.161116
# Iteration:   312   Dual objective     =          1911.562386
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1834.207531
# Iteration:     3   Dual objective     =         20682.067881
# Iteration:    64   Dual objective     =          7613.606416
# Iteration:   126   Dual objective     =          5030.478994
# Iteration:   188   Dual objective     =          3771.355200
# Iteration:   250   Dual objective     =          3086.630128
# Iteration:   312   Dual objective     =          2257.355385
# Iteration:   374   Dual objective     =          1834.207860
# Perturbation started.
# Iteration:   411   Dual objective     =          1834.207860
# Iteration:   473   Dual objective     =          1834.207789
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1889.336861
# Iteration:     3   Dual objective     =          8113.012210
# Iteration:    64   Dual objective     =          3564.700866
# Iteration:   126   Dual objective     =          2448.222635
# Iteration:   188   Dual objective     =          1999.086049
# Iteration:   250   Dual objective     =          1846.068888
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1863.419141
# Iteration:     3   Dual objective     =         13322.649222
# Iteration:    64   Dual objective     =          5311.604780
# Iteration:   126   Dual objective     =          3493.548070
# Iteration:   188   Dual objective     =          2751.629799
# Iteration:   250   Dual objective     =          2300.504165
# Iteration:   312   Dual objective     =          2032.379064
# Iteration:   374   Dual objective     =          1863.419470
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1702.348181
# Iteration:     3   Dual objective     =          9819.172077
# Iteration:    64   Dual objective     =          3927.634684
# Iteration:   126   Dual objective     =          2661.742759
# Iteration:   188   Dual objective     =          2149.601563
# Iteration:   250   Dual objective     =          1854.750959
# Iteration:   312   Dual objective     =          1730.398203
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.02 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1889.720551
# Iteration:     3   Dual objective     =         12406.881549
# Iteration:    64   Dual objective     =          5323.336781
# Iteration:   126   Dual objective     =          3764.287323
# Iteration:   188   Dual objective     =          2952.728427
# Iteration:   250   Dual objective     =          2437.179832
# Iteration:   312   Dual objective     =          2054.481258
# Iteration:   374   Dual objective     =          1889.720880
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1818.627081
# Iteration:     3   Dual objective     =         14966.797356
# Iteration:    64   Dual objective     =          5731.960443
# Iteration:   126   Dual objective     =          3802.876618
# Iteration:   188   Dual objective     =          3033.981852
# Iteration:   250   Dual objective     =          2546.923622
# Iteration:   312   Dual objective     =          2129.779045
# Iteration:   374   Dual objective     =          1818.627410
# Perturbation started.
# Iteration:   411   Dual objective     =          1818.627410
# Iteration:   473   Dual objective     =          1818.627396
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1796.520981
# Iteration:     3   Dual objective     =         12782.567024
# Iteration:    64   Dual objective     =          5409.655253
# Iteration:   126   Dual objective     =          3519.661156
# Iteration:   188   Dual objective     =          2696.928568
# Iteration:   250   Dual objective     =          2252.608056
# Iteration:   312   Dual objective     =          1951.178053
# Iteration:   374   Dual objective     =          1796.521310
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1767.906551
# Iteration:     3   Dual objective     =         19631.582049
# Iteration:    64   Dual objective     =          7951.509867
# Iteration:   126   Dual objective     =          5125.446810
# Iteration:   188   Dual objective     =          3778.211413
# Iteration:   250   Dual objective     =          2937.333011
# Iteration:   312   Dual objective     =          2287.910077
# Iteration:   374   Dual objective     =          1767.906880
# Perturbation started.
# Iteration:   411   Dual objective     =          1767.906880
# Iteration:   473   Dual objective     =          1767.906795
# Removing perturbation.
#
# Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 660 rows and 0 columns.
# Reduced LP has 332 rows, 660 columns, and 1320 nonzeros.
# Presolve time = 0.00 sec. (0.63 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =          1786.089161
# Iteration:     3   Dual objective     =         13826.272805
# Iteration:    64   Dual objective     =          5503.438560
# Iteration:   126   Dual objective     =          3586.767155
# Iteration:   188   Dual objective     =          2865.379590
# Iteration:   250   Dual objective     =          2366.033984
# Iteration:   312   Dual objective     =          1968.736222
# Iteration:   374   Dual objective     =          1786.089490
# Perturbation started.
# Iteration:   411   Dual objective     =          1786.089490
# Removing perturbation.
#
#       n  ticks_mean     ticks_std
# 0     5        0.01  1.734723e-18
# 1    10        0.02  3.469447e-18
# 2    15        0.03  6.938894e-18
# 3    20        0.04  6.938894e-18
# 4    25        0.05  6.938894e-18
# ..  ...         ...           ...
# 61  310        0.59  0.000000e+00
# 62  315        0.60  1.110223e-16
# 63  320        0.61  1.110223e-16
# 64  325        0.62  1.110223e-16
# 65  330        0.63  1.110223e-16
#
# [66 rows x 3 columns]
